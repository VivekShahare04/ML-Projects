# %% [markdown]
# <a href="https://colab.research.google.com/github/VivekShahare04/ML-Projects/blob/main/Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('Salary_dataset.csv')
dataset
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# 20          20              6.9   91739.0
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       30 non-null     int64
#  1   YearsExperience  30 non-null     float64
#  2   Salary           30 non-null     float64
# dtypes: float64(2), int64(1)
# memory usage: 848.0 bytes

# %%
dataset.isnull().sum()
# Out:
# Unnamed: 0         0
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
dataset.shape
# Out:
# (30, 3)

# %%
dataset.describe()
# Out:
#        Unnamed: 0  YearsExperience         Salary
# count   30.000000        30.000000      30.000000
# mean    14.500000         5.413333   76004.000000
# std      8.803408         2.837888   27414.429785
# min      0.000000         1.200000   37732.000000
# 25%      7.250000         3.300000   56721.750000
# 50%     14.500000         4.800000   65238.000000
# 75%     21.750000         7.800000  100545.750000
# max     29.000000        10.600000  122392.000000

# %%
dataset = dataset.drop('Unnamed: 0',axis=1)

# %%
dataset.head()
# Out:
#    YearsExperience   Salary
# 0              1.2  39344.0
# 1              1.4  46206.0
# 2              1.6  37732.0
# 3              2.1  43526.0
# 4              2.3  39892.0

# %%
X = dataset.iloc[:,0]
y = dataset.iloc[:,1]

# %%
X.head()
# Out:
# 0    1.2
# 1    1.4
# 2    1.6
# 3    2.1
# 4    2.3
# Name: YearsExperience, dtype: float64

# %%
y.head()
# Out:
# 0    39344.0
# 1    46206.0
# 2    37732.0
# 3    43526.0
# 4    39892.0
# Name: Salary, dtype: float64

# %%
plt.figure(figsize=(10, 5))
plt.scatter(X, y, color='blue')  # actual data
plt.plot(X, y, color='red', linewidth=2)  # regression line
plt.title('Best Fit Line')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(np.array(X_train).reshape(-1,1),y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(np.array(X_test).reshape(-1,1))
y_pred
# Out:
# array([115440.88180109,  71397.10622651, 102321.45928951,  75145.51265839,
#         55466.37889103,  60151.88693088, 122000.59305688, 107006.96732936])

# %%
plt.figure(figsize=(10, 5))
plt.scatter(X, y, color='blue')  # actual data
plt.plot(X_test, y_pred, color='red', linewidth=2)  # regression line
plt.title('Best Fit Line')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.9347210011126783

# %%
sample = ([[1.4]])
predict_class = model.predict(sample)
predict_class
# Out:
# array([37661.44833961])
